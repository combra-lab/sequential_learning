# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import numpy as np

from data_loaders import load_monkey_I, load_monkey_M
from models import ANNModel
from utils import sequential_learning

# %%
monkey_I_sequential, monkey_I_falloff = sequential_learning(file_path= 'monkey_I_data', save_folder= 'monkey_I_model_states', monkey = "I")
# Out:
# ['indy_20160624_03.mat', 'indy_20160627_01.mat', 'indy_20160915_01.mat', 'indy_20160916_01.mat', 'indy_20160921_01.mat', 'indy_20160927_06.mat', 'indy_20160927_04.mat', 'indy_20160930_05.mat', 'indy_20160930_02.mat', 'indy_20161005_06.mat', 'indy_20161006_02.mat', 'indy_20161007_02.mat']
# Loading indy_20160624_03.mat
# [1,   200] loss: 0.087
# [2,   200] loss: 0.063
# [3,   200] loss: 0.056
# [4,   200] loss: 0.053
# [5,   200] loss: 0.050
# [6,   200] loss: 0.048
# [7,   200] loss: 0.046
# [8,   200] loss: 0.045
# [9,   200] loss: 0.044
# [10,   200] loss: 0.044
# [11,   200] loss: 0.043
# [12,   200] loss: 0.042
# [13,   200] loss: 0.042
# [14,   200] loss: 0.041
# [15,   200] loss: 0.041
# [16,   200] loss: 0.041
# [17,   200] loss: 0.040
# [18,   200] loss: 0.039
# [19,   200] loss: 0.039
# [20,   200] loss: 0.038
# [21,   200] loss: 0.038
# [22,   200] loss: 0.038
# [23,   200] loss: 0.038
# [24,   200] loss: 0.037
# [25,   200] loss: 0.037
# Loading indy_20160624_03.mat
# ...

# %%
plt.plot(np.mean(monkey_I_sequential, axis = 1))
plt.plot(np.mean(monkey_I_falloff, axis = 1))

# %%
monkey_M_sequential, monkey_M_falloff = sequential_learning(file_path= 'monkey_M_data', save_folder= 'monkey_M_model_states', monkey = "M")
# Out:
# ['sub-M_ses-CO-20140626_behavior+ecephys.nwb', 'sub-M_ses-CO-20140627_behavior+ecephys.nwb', 'sub-M_ses-CO-20140929_behavior+ecephys.nwb', 'sub-M_ses-CO-20150610_behavior+ecephys.nwb', 'sub-M_ses-CO-20150611_behavior+ecephys.nwb', 'sub-M_ses-CO-20150612_behavior+ecephys.nwb', 'sub-M_ses-CO-20150615_behavior+ecephys.nwb', 'sub-M_ses-CO-20150616_behavior+ecephys.nwb', 'sub-M_ses-CO-20150617_behavior+ecephys.nwb']
# Loading sub-M_ses-CO-20140626_behavior+ecephys.nwb
# [1,   200] loss: 16.994
# [1,   400] loss: 12.290
# [1,   600] loss: 11.891
# [1,   800] loss: 11.200
# [1,  1000] loss: 11.012
# [1,  1200] loss: 10.845
# [1,  1400] loss: 10.421
# [2,   200] loss: 10.365
# [2,   400] loss: 10.107
# [2,   600] loss: 10.027
# [2,   800] loss: 9.987
# [2,  1000] loss: 9.758
# [2,  1200] loss: 10.046
# [2,  1400] loss: 9.976
# [3,   200] loss: 9.841
# [3,   400] loss: 9.903
# [3,   600] loss: 9.896
# [3,   800] loss: 9.658
# [3,  1000] loss: 9.755
# [3,  1200] loss: 9.531
# ...

# %%
print(monkey_M_falloff)
# Out:
# [[ 0.44658387  0.60210121  0.69087899  0.63389415  0.59657383  0.52614176
#    0.64150643  0.6936031   0.65455914  0.58878767  0.54526138  0.64730561
#    0.68125725  0.58340156  0.60057962]
#  [ 0.38032722  0.47331202  0.42340893  0.35552967  0.37106156  0.41174638
#    0.40604305  0.41112584  0.40946072  0.40333557  0.43835342  0.45033038
#    0.39321625  0.34076166  0.40341318]
#  [-0.07347894  0.17091042  0.14802527  0.11534476  0.01098478  0.17044711
#   -0.19244516  0.08068478  0.15118009 -0.14129353  0.17096299 -0.1333133
#    0.17809421  0.16960722 -0.08193862]
#  [ 0.12106699  0.08407605  0.02734441  0.10001391  0.14448822  0.12496924
#    0.12838078 -0.00811481  0.01734108  0.10651118  0.09450448  0.03830349
#    0.0017435   0.10400736  0.074911  ]
#  [ 0.09184724  0.01057112  0.06435233  0.11121172  0.23981822  0.04136842
#    0.20965576  0.1738072   0.12659073  0.09606475 -0.01612866  0.23906094
#   -0.01274157  0.15178412  0.10527456]
# ...

# %%
plt.plot(np.mean(monkey_M_sequential, axis = 1))
plt.plot(np.mean(monkey_M_falloff, axis = 1))
